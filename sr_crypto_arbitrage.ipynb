# %% [markdown]
# ## Crypto Arbitrage
#
# In this Challenge, you'll take on the role of an analyst at a high-tech investment firm. The vice president (VP) of your department is considering arbitrage opportunities in Bitcoin and other cryptocurrencies. As Bitcoin trades on markets across the globe, can you capitalize on simultaneous price dislocations in those markets by using the powers of Pandas?
#
# For this assignment, you’ll sort through historical trade data for Bitcoin on two exchanges: Bitstamp and Coinbase. Your task is to apply the three phases of financial analysis to determine if any arbitrage opportunities exist for Bitcoin.
#
# This aspect of the Challenge will consist of 3 phases.
#
# 1. Collect the data.
#
# 2. Prepare the data.
#
# 3. Analyze the data.

# %% [markdown]
# ###  Import the required libraries and dependencies.

# %%
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ## Collect the Data
#
# To collect the data that you’ll need, complete the following steps:
#
# Instructions.
#
# 1. Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.
#
# 2. Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.
#
# 3. Repeat Steps 1 and 2 for `coinbase.csv` file.

# %% [markdown]
# ### Step 1: Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.

# %%
# Read in the CSV file called "bitstamp.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Date"
# Set the parse_dates and infer_datetime_format parameters
# YOUR CODE HERE
bitstamp = pd.read_csv(
    Path('./Resources/bitstamp.csv'),
    index_col = 'Timestamp',
    parse_dates = True,
    infer_datetime_format = True
)

# %% [markdown]
# ### Step 2: Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
# YOUR CODE HERE
bitstamp.head()
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329

# %%
# verify the tail end of the data
bitstamp.tail()
# Out:
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6935.01  6939.07  6922.56  $6922.56    1.044354
# 2018-03-31 23:56:00  6922.02  6922.02  6918.00  $6920.32    3.069539
# 2018-03-31 23:57:00  6920.33  6936.42  6920.33  $6934.72   28.239049
# 2018-03-31 23:58:00  6927.65  6929.42  6927.65  $6927.65    0.839507
# 2018-03-31 23:59:00  6929.98  6929.98  6928.00  $6928.01    0.209363
#
#                         USD Volume  Weighted Price
# Timestamp
# 2018-03-31 23:55:00    7240.034602     6932.550078
# 2018-03-31 23:56:00   21245.076275     6921.260233
# 2018-03-31 23:57:00  195789.408220     6933.286106
# 2018-03-31 23:58:00    5817.007705     6929.080007
# 2018-03-31 23:59:00    1450.735763     6929.289993

# %% [markdown]
# ### Step 3: Repeat Steps 1 and 2 for `coinbase.csv` file.

# %%
# Read in the CSV file called "coinbase.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Timestamp"
# Set the parse_dates and infer_datetime_format parameters
# YOUR CODE HERE
coinbase = pd.read_csv(
    Path('./Resources/coinbase.csv'),
    index_col = 'Timestamp',
    parse_dates = True,
    infer_datetime_format = True
)

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
# YOUR CODE HERE
coinbase.head()
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401

# %%
# verify the tail end of the data
coinbase.tail()
# Out:
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6945.20  6948.06  6930.00   $6930.0    5.802288
# 2018-03-31 23:56:00  6930.00  6930.01  6930.00  $6930.01    0.625053
# 2018-03-31 23:57:00  6930.01  6933.91  6930.01  $6933.91    0.776431
# 2018-03-31 23:58:00  6933.91  6938.00  6933.90  $6937.31    0.133413
# 2018-03-31 23:59:00  6937.30  6937.30  6931.09   $6934.0    1.012720
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-03-31 23:55:00  40243.918480     6935.869979
# 2018-03-31 23:56:00   4331.620701     6930.005567
# 2018-03-31 23:57:00   5382.532162     6932.405747
# 2018-03-31 23:58:00    925.356547     6936.048538
# 2018-03-31 23:59:00   7022.275088     6934.070316

# %% [markdown]
# ## Prepare the Data
#
# To prepare and clean your data for analysis, complete the following steps:
#
# 1. For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.
#
# 2. Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.
#
# 3. Convert the data type of the Close column to a `float`.
#
# 4. Review the data for duplicated values, and drop them if necessary.
#
# 5. Repeat Steps 1–4 for the coinbase DataFrame.

# %% [markdown]
# ### Step 1: For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.

# %%
# For the bitstamp DataFrame, replace or drop all NaNs or missing values in the DataFrame
# YOUR CODE HERE
null_count = bitstamp.isnull().sum()

# %%
print(f"The number of 'NaN' values in the 'bitstamp.csv' file are:\n")
print(null_count)
# Out:
# The number of 'NaN' values in the 'bitstamp.csv' file are:
#
# Open              473
# High              473
# Low               473
# Close               0
# BTC Volume        473
# USD Volume        473
# Weighted Price    473
# dtype: int64

# %%
# Drop Null Values
print(f"Dropping the 'NaN' values from the 'bitstamp.csv' file ...")
bitstamp = bitstamp.dropna()
# Out:
# Dropping the 'NaN' values from the 'bitstamp.csv' file ...

# %%
# Verify that NaNs have been dropped
null_count = bitstamp.isnull().sum()

# %%
print(f"The number of 'NaN' values in the 'bitstamp.csv' file are:\n")
print(null_count)
# Out:
# The number of 'NaN' values in the 'bitstamp.csv' file are:
#
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %% [markdown]
# ### Step 2: Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.

# %%
# Use the str.replace function to remove the dollar sign, $
# YOUR CODE HERE
print(f"Initial: The column labeled as 'Close' has the '$' sign in its values, as shown:")
bitstamp.head(5)
# Out:
# Initial: The column labeled as 'Close' has the '$' sign in its values, as shown:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329

# %%
# Change type if it is an object.
if bitstamp.dtypes["Close"] == 'object':
    print(f"Removing the '$' sign from values ...")
    bitstamp.loc[:,"Close"] = bitstamp.loc[:,"Close"].str.replace("$","")
# Out:
# Removing the '$' sign from values ...
# C:\Users\sraghib\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   after removing the cwd from sys.path.

# %%
print(f"Final: The column labeled 'Close' has the '$' sign removed from its values, as shown:")
bitstamp.head(5)
# Out:
# Final: The column labeled 'Close' has the '$' sign removed from its values, as shown:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329

# %% [markdown]
# ### Step 3: Convert the data type of the Close column to a `float`.

# %%
# Convert the Close data type to a float
# YOUR CODE HERE

if bitstamp.dtypes["Close"] != 'float64':
    print(f"The column labeled as 'Close' has the wrong type for further calculations:\n")
    print(bitstamp.dtypes)
# Out:
# The column labeled as 'Close' has the wrong type for further calculations:
#
# Open              float64
# High              float64
# Low               float64
# Close              object
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %%
if bitstamp.dtypes["Close"] != 'float64':
    print(f"Converting the type to 'float' ...")
    bitstamp.loc[:,"Close"] = bitstamp.loc[:,"Close"].astype("float")
# Out:
# Converting the type to 'float' ...

# %%
if bitstamp.dtypes["Close"] == 'float64':
    print(f"The column labeled as 'Close' now has the correct type for further calculations:\n")
    print(bitstamp.dtypes)
# Out:
# The column labeled as 'Close' now has the correct type for further calculations:
#
# Open              float64
# High              float64
# Low               float64
# Close             float64
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %% [markdown]
# ### Step 4: Review the data for duplicated values, and drop them if necessary.

# %%
# Review the data for duplicate values, and drop them if necessary
# YOUR CODE HERE
print(f"Below is the list of 'duplicates': ('True' means duplicates exist.)")
bitstamp.duplicated()
# Out:
# Below is the list of 'duplicates': ('True' means duplicates exist.)
# Timestamp
# 2018-01-01 00:00:00    False
# 2018-01-01 00:01:00    False
# 2018-01-01 00:02:00    False
# 2018-01-01 00:03:00    False
# 2018-01-01 00:04:00    False
#                        ...
# 2018-03-31 23:55:00    False
# 2018-03-31 23:56:00    False
# 2018-03-31 23:57:00    False
# 2018-03-31 23:58:00    False
# 2018-03-31 23:59:00    False
# Length: 129067, dtype: bool

# %% [markdown]
# ### Step 5: Repeat Steps 1–4 for the coinbase DataFrame.

# %%
# For the bitstamp DataFrame, replace or drop all NaNs or missing values in the DataFrame
# YOUR CODE HERE
null_count = coinbase.isnull().sum()

# %%
print(f"The number of 'NaN' values in the 'coinbase.csv' file are:\n")
print(null_count)
# Out:
# The number of 'NaN' values in the 'coinbase.csv' file are:
#
# Open              218
# High              218
# Low               218
# Close               0
# BTC Volume        218
# USD Volume        218
# Weighted Price    218
# dtype: int64

# %%
# Drop Null Values
print(f"Dropping the 'NaN' values from the 'coinbase.csv' file ...")
coinbase = coinbase.dropna()
# Out:
# Dropping the 'NaN' values from the 'coinbase.csv' file ...

# %%
# Verify that NaNs have been dropped
null_count = coinbase.isnull().sum()

# %%
print(f"The number of 'NaN' values in the 'coinbase.csv' file are:\n")
print(null_count)
# Out:
# The number of 'NaN' values in the 'coinbase.csv' file are:
#
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %% [markdown]
# ### Step 2: Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.

# %%
# Use the str.replace function to remove the dollar sign, $
# YOUR CODE HERE
print(f"Initial: The column labeled as 'Close' has the '$' sign in its values, as shown:")
coinbase.head(5)
# Out:
# Initial: The column labeled as 'Close' has the '$' sign in its values, as shown:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401

# %%
# Change type if it is an object.
if coinbase.dtypes["Close"] == 'object':
    print(f"Removing the '$' sign from values ...")
    coinbase.loc[:,"Close"] = coinbase.loc[:,"Close"].str.replace("$","")
# Out:
# Removing the '$' sign from values ...
# C:\Users\sraghib\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   after removing the cwd from sys.path.

# %%
print(f"Final: The column labeled 'Close' has the '$' sign removed from its values, as shown:")
coinbase.head(5)
# Out:
# Final: The column labeled 'Close' has the '$' sign removed from its values, as shown:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401

# %% [markdown]
# ### Step 3: Convert the data type of the Close column to a `float`.

# %%
# Convert the Close data type to a float
# YOUR CODE HERE

if coinbase.dtypes["Close"] != 'float64':
    print(f"The column labeled as 'Close' has the wrong type for further calculations:\n")
    print(coinbase.dtypes)
# Out:
# The column labeled as 'Close' has the wrong type for further calculations:
#
# Open              float64
# High              float64
# Low               float64
# Close              object
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %%
if coinbase.dtypes["Close"] != 'float64':
    print(f"Converting the type to 'float' ...")
    coinbase.loc[:,"Close"] = coinbase.loc[:,"Close"].astype("float")
# Out:
# Converting the type to 'float' ...

# %%
if coinbase.dtypes["Close"] == 'float64':
    print(f"The column labeled as 'Close' now has the correct type for further calculations:\n")
    print(coinbase.dtypes)
# Out:
# The column labeled as 'Close' now has the correct type for further calculations:
#
# Open              float64
# High              float64
# Low               float64
# Close             float64
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %% [markdown]
# ### Step 4: Review the data for duplicated values, and drop them if necessary.

# %%
# Review the data for duplicate values, and drop them if necessary
# YOUR CODE HERE
print(f"Below is the list of 'duplicates': ('True' means duplicates exist.)")
coinbase.duplicated()
# Out:
# Below is the list of 'duplicates': ('True' means duplicates exist.)
# Timestamp
# 2018-01-01 00:00:00    False
# 2018-01-01 00:01:00    False
# 2018-01-01 00:02:00    False
# 2018-01-01 00:03:00    False
# 2018-01-01 00:04:00    False
#                        ...
# 2018-03-31 23:55:00    False
# 2018-03-31 23:56:00    False
# 2018-03-31 23:57:00    False
# 2018-03-31 23:58:00    False
# 2018-03-31 23:59:00    False
# Length: 129322, dtype: bool

# %%
bitstamp.describe()
# Out:
#                 Open           High            Low          Close  \
# count  129067.000000  129067.000000  129067.000000  129067.000000
# mean    10459.993683   10472.970114   10446.214703   10459.842453
# std      2315.909269    2318.929342    2312.331601    2315.976088
# min      5945.950000    5975.060000    5920.720000    5944.000000
# 25%      8613.985000    8621.655000    8604.440000    8613.370000
# 50%     10145.300000   10156.410000   10131.740000   10145.950000
# 75%     11444.455000   11453.990000   11431.970000   11444.810000
# max     17234.980000   17234.990000   17214.960000   17234.980000
#
#           BTC Volume    USD Volume  Weighted Price
# count  129067.000000  1.290670e+05   129067.000000
# mean       11.792878  1.177496e+05    10459.384448
# std        21.799938  2.070551e+05     2315.723480
# min         0.000039  3.333436e-01     5949.997212
# 25%         1.711874  1.773244e+04     8613.587020
# 50%         4.994095  5.188050e+04    10144.740411
# ...

# %% [markdown]
# ## Analyze the Data
#
# Your analysis consists of the following tasks:
#
# 1. Choose the columns of data on which to focus your analysis.
#
# 2. Get the summary statistics and plot the data.
#
# 3. Focus your analysis on specific dates.
#
# 4. Calculate the arbitrage profits.

# %% [markdown]
# ### Step 1: Choose columns of data on which to focus your analysis.
#
# Select the data you want to analyze. Use `loc` or `iloc` to select the following columns of data for both the bitstamp and coinbase DataFrames:
#
# * Timestamp (index)
#
# * Close

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from bitstamp DataFrame
# YOUR CODE HERE
bitstamp_sliced = bitstamp.loc[:, 'Close']

# Review the first five rows of the DataFrame
# YOUR CODE HERE
print(f"List of values at 'Close' for Bitcoin at 'Bitstamp':")
bitstamp_sliced.head(5)
# Out:
# List of values at 'Close' for Bitcoin at 'Bitstamp':
# Timestamp
# 2018-01-01 00:00:00    13646.48
# 2018-01-01 00:01:00    13658.75
# 2018-01-01 00:02:00    13610.22
# 2018-01-01 00:03:00    13639.09
# 2018-01-01 00:04:00    13620.00
# Name: Close, dtype: float64

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from coinbase DataFrame
# YOUR CODE HERE
coinbase_sliced = coinbase.loc[:, 'Close']

# Review the first five rows of the DataFrame
# YOUR CODE HERE
print(f"List of values at 'Close' for Bitcoin at 'Coinbase':")
coinbase_sliced.head(5)
# Out:
# List of values at 'Close' for Bitcoin at 'Coinbase':
# Timestamp
# 2018-01-01 00:00:00    13608.49
# 2018-01-01 00:01:00    13601.66
# 2018-01-01 00:02:00    13580.00
# 2018-01-01 00:03:00    13550.34
# 2018-01-01 00:04:00    13583.44
# Name: Close, dtype: float64

# %% [markdown]
# ### Step 2: Get summary statistics and plot the data.
#
# Sort through the time series data associated with the bitstamp and coinbase DataFrames to identify potential arbitrage opportunities. To do so, complete the following steps:
#
# 1. Generate the summary statistics for each DataFrame by using the `describe` function.
#
# 2. For each DataFrame, create a line plot for the full period of time in the dataset. Be sure to tailor the figure size, title, and color to each visualization.
#
# 3. In one plot, overlay the visualizations that you created in Step 2 for bitstamp and coinbase. Be sure to adjust the legend and title for this new visualization.
#
# 4. Using the `loc` and `plot` functions, plot the price action of the assets on each exchange for different dates and times. Your goal is to evaluate how the spread between the two exchanges changed across the time period that the datasets define. Did the degree of spread change as time progressed?

# %%
# Generate the summary statistics for the bitstamp DataFrame
# YOUR CODE HERE
print(f"The stats on 'bitstamp' exchange are:")
bitstamp_sliced.describe()
# Out:
# The stats on 'bitstamp' exchange are:
# count    129067.000000
# mean      10459.842453
# std        2315.976088
# min        5944.000000
# 25%        8613.370000
# 50%       10145.950000
# 75%       11444.810000
# max       17234.980000
# Name: Close, dtype: float64

# %%
# Generate the summary statistics for the coinbase DataFrame
# YOUR CODE HERE
print(f"The stats on 'coinbase' exchange are:")
coinbase_sliced.describe()
# Out:
# The stats on 'coinbase' exchange are:
# count    129322.000000
# mean      10449.140958
# std        2317.197419
# min        5882.310000
# 25%        8609.230000
# 50%       10137.440000
# 75%       11397.237500
# max       17177.990000
# Name: Close, dtype: float64

# %%
# Create a line plot for the bitstamp DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
# YOUR CODE HERE
print(f"Plotting the entire set of data for exchange: Bitstamp")
print()
bitstamp_sliced.plot(figsize=(16,8), title="Exchange: Bitstamp", color="purple")
# Out:
# Plotting the entire set of data for exchange: Bitstamp
# <AxesSubplot:title={'center':'Exchange: Bitstamp'}, xlabel='Timestamp'>

# %%
# Create a line plot for the coinbase DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
# YOUR CODE HERE
print(f"Plotting the entire set of data for exchange: Coinbase")
print()
coinbase_sliced.plot(figsize=(16,8), title="Exchange: Coinbase", color="orange")
# Out:
# Plotting the entire set of data for exchange: Coinbase
# <AxesSubplot:title={'center':'Exchange: Coinbase'}, xlabel='Timestamp'>

# %%
# Overlay the visualizations for the bitstamp and coinbase DataFrames in one plot
# The plot should visualize the prices over the full lenth of the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
# YOUR CODE HERE
print(f"The overlay plot show that thru out the timeline thare are price points that are not in sync between the two exchanges.")
print()
#bitstamp['Close'].dtypes
bitstamp_sliced.plot(legend=True, figsize=(16, 8), title="Bitstam vs Coinbase as an Overlay", color="purple", label="Timestamp")
coinbase_sliced.plot(legend=True, figsize=(16, 8), color="orange", label="Coinbase")
# Out:
# The overlay plot show that thru out the timeline thare are price points that are not in sync between the two exchanges.
# <AxesSubplot:title={'center':'Bitstam vs Coinbase as an Overlay'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period early in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
# YOUR CODE HERE
print(f"This overlay plot show the beginning of the dataset, i.e. January'2018.")
print()
bitstamp_sliced.loc['2018-01-01':'2018-01-31'].plot(legend=True, figsize=(16, 8), title="Bitstam vs Coinbase as an Overlay: January 2018", color="purple", label="Timestamp")
coinbase_sliced.loc['2018-01-01':'2018-01-31'].plot(legend=True, figsize=(16, 8), color="orange", label="Coinbase")
# Out:
# This overlay plot show the beginning of the dataset, i.e. January'2018.
# <AxesSubplot:title={'center':'Bitstam vs Coinbase as an Overlay: January 2018'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period later in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label 
# YOUR CODE HERE
print(f"This overlay plot show the beginning of the dataset, i.e. March'2018.")
print()
bitstamp_sliced.loc['2018-03-01':'2018-03-31'].plot(legend=True, figsize=(16, 8), title="Bitstam vs Coinbase as an Overlay: March 2018", color="purple", label="Timestamp")
coinbase_sliced.loc['2018-03-01':'2018-03-31'].plot(legend=True, figsize=(16, 8), color="orange", label="Coinbase")
# Out:
# This overlay plot show the beginning of the dataset, i.e. March'2018.
# <AxesSubplot:title={'center':'Bitstam vs Coinbase as an Overlay: March 2018'}, xlabel='Timestamp'>

# %% [markdown]
# **Question** Based on the visualizations of the different time periods, has the degree of spread change as time progressed?
#
# **Answer** YOUR ANSWER HERE
# Yes, The degree of spread between January'2018 and March'2018 has changed.

# %% [markdown]
# ### Step 3: Focus Your Analysis on Specific Dates
#
# Focus your analysis on specific dates by completing the following steps:
#
# 1. Select three dates to evaluate for arbitrage profitability. Choose one date that’s early in the dataset, one from the middle of the dataset, and one from the later part of the time period.
#
# 2. For each of the three dates, generate the summary statistics and then create a box plot. This big-picture view is meant to help you gain a better understanding of the data before you perform your arbitrage calculations. As you compare the data, what conclusions can you draw?

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day early in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
# YOUR CODE HERE
print(f"This overlay plot is for ONE day early in the dataset - January'15th:")
print()
bitstamp_sliced.loc['2018-01-15'].plot(figsize=(16, 8), legend=True, title="Overlay plot for January'15th", color="purple", label="Bitstamp")
coinbase_sliced.loc['2018-01-15'].plot(figsize=(16, 8), legend=True, color="orange", label="Coinbase")
# Out:
# This overlay plot is for ONE day early in the dataset - January'15th:
# <AxesSubplot:title={'center':"Overlay plot for January'15th"}, xlabel='Timestamp'>

# %%
print(f"This overlay plot is for ONE day early in the dataset - January'15th between 8pm & 10pm:")
print()
bitstamp_sliced.loc['2018-01-15 20' : '2018-01-15 21'].plot(figsize=(16, 8), legend=True, title="Overlay plot for January'15th 8pm to 10pm", color="purple", label="Bitstamp")
coinbase_sliced.loc['2018-01-15 20' : '2018-01-15 21'].plot(figsize=(16, 8), legend=True, color="orange", label="Coinbase")
# Out:
# This overlay plot is for ONE day early in the dataset - January'15th between 8pm & 10pm:
# <AxesSubplot:title={'center':"Overlay plot for January'15th 8pm to 10pm"}, xlabel='Timestamp'>

# %%
# Using the early date that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
# YOUR CODE HERE
print(f"This Arbitrage spread is for ONE day early in the dataset - January'15th between 8pm & 10pm:")
print()
arbitrage_spread_early = coinbase_sliced.loc['2018-01-15 20' : '2018-01-15 21'] - bitstamp_sliced.loc['2018-01-15 20' : '2018-01-15 21']

# Generate summary statistics for the early DataFrame
# YOUR CODE HERE
arbitrage_spread_early.describe()
# Out:
# This Arbitrage spread is for ONE day early in the dataset - January'15th between 8pm & 10pm:
# count    120.000000
# mean      14.173917
# std       33.346039
# min      -96.440000
# 25%       -6.837500
# 50%       17.260000
# 75%       37.160000
# max      106.080000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from early in the dataset in a box plot
# YOUR CODE HERE
print(f"Plotting the Arbitrage spread (as a box plot) for ONE day early in the dataset - January'15th between 8pm & 10pm:")
print()
arbitrage_spread_early.plot(kind='box')
# Out:
# Plotting the Arbitrage spread (as a box plot) for ONE day early in the dataset - January'15th between 8pm & 10pm:
# <AxesSubplot:>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from the middle of the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
# YOUR CODE HERE
print(f"This overlay plot is for ONE day in the middle of the dataset - February'15th:")
print()
bitstamp_sliced.loc['2018-02-15'].plot(figsize=(16, 8), legend=True, title="Overlay plot for Februrary'15th", color="purple", label="Bitstamp")
coinbase_sliced.loc['2018-02-15'].plot(figsize=(16, 8), legend=True, color="orange", label="Coinbase")
# Out:
# This overlay plot is for ONE day in the middle of the dataset - February'15th:
# <AxesSubplot:title={'center':"Overlay plot for Februrary'15th"}, xlabel='Timestamp'>

# %%
print(f"This overlay plot for for ONE day in the middle of the dataset - January'15th between 9am & 10am:")
print()
bitstamp_sliced.loc['2018-02-15 09' : '2018-02-15 10'].plot(figsize=(16, 8), legend=True, title="Overlay plot for February'15th 9am & 10am", color="purple", label="Bitstamp")
coinbase_sliced.loc['2018-02-15 09' : '2018-02-15 10'].plot(figsize=(16, 8), legend=True, color="orange", label="Coinbase")
# Out:
# This overlay plot for for ONE day in the middle of the dataset - January'15th between 9am & 10am:
# <AxesSubplot:title={'center':"Overlay plot for February'15th 9am & 10am"}, xlabel='Timestamp'>

# %%
# Using the date in the middle that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
# YOUR CODE HERE
print(f"This Arbitrage spread is for ONE day in the middle of the dataset - Februrary'15th between 8am & 11am:")
print()
arbitrage_spread_middle = coinbase_sliced.loc['2018-02-15 09' : '2018-02-15 10'] - bitstamp_sliced.loc['2018-02-15 09' : '2018-02-15 10']

# Generate summary statistics 
# YOUR CODE HERE
arbitrage_spread_middle.describe()
# Out:
# This Arbitrage spread is for ONE day in the middle of the dataset - Februrary'15th between 8am & 11am:
# count    120.000000
# mean       2.258417
# std       11.374937
# min      -28.820000
# 25%       -5.730000
# 50%        3.765000
# 75%       10.642500
# max       27.480000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from the middle of the dataset in a box plot
# YOUR CODE HERE
print(f"Plotting the Arbitrage spread (as a box plot) for ONE day in the middle of the dataset - January'15th between 8pm & 10pm:")
print()
arbitrage_spread_middle.plot(kind='box')
# Out:
# Plotting the Arbitrage spread (as a box plot) for ONE day in the middle of the dataset - January'15th between 8pm & 10pm:
# <AxesSubplot:>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from late in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
# YOUR CODE HERE
print(f"This overlay plot is for ONE day in the later part of the dataset - March'15th:")
print()
bitstamp_sliced.loc['2018-03-15'].plot(figsize=(16, 8), legend=True, title="Overlay plot for March'15th", color="purple", label="Bitstamp")
coinbase_sliced.loc['2018-03-15'].plot(figsize=(16, 8), legend=True, color="orange", label="Coinbase")
# Out:
# This overlay plot is for ONE day in the later part of the dataset - March'15th:
# <AxesSubplot:title={'center':"Overlay plot for March'15th"}, xlabel='Timestamp'>

# %%
print(f"This overlay plot is for ONE day early in the dataset - March'15th between 2am & 4am:")
print()
bitstamp_sliced.loc['2018-03-15 02' : '2018-03-15 03'].plot(figsize=(16, 8), legend=True, title="Overlay plot for March'2am to 4am", color="purple", label="Bitstamp")
coinbase_sliced.loc['2018-03-15 02' : '2018-03-15 03'].plot(figsize=(16, 8), legend=True, color="orange", label="Coinbase")
# Out:
# This overlay plot is for ONE day early in the dataset - March'15th between 2am & 4am:
# <AxesSubplot:title={'center':"Overlay plot for March'2am to 4am"}, xlabel='Timestamp'>

# %%
# Using the date from the late that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
# YOUR CODE HERE
print(f"This Arbitrage spread is for ONE day in the later part of the dataset - March'15th between 2am & 4am:")
print()
arbitrage_spread_late = coinbase_sliced.loc['2018-03-15 02' : '2018-03-15 03'] - bitstamp_sliced.loc['2018-03-15 02' : '2018-03-15 03']

# Generate summary statistics for the late DataFrame
# YOUR CODE HERE
arbitrage_spread_late.describe()
# Out:
# This Arbitrage spread is for ONE day in the later part of the dataset - March'15th between 2am & 4am:
# count    120.000000
# mean      -8.457583
# std        9.182003
# min      -30.630000
# 25%      -13.695000
# 50%       -7.970000
# 75%       -2.557500
# max       15.600000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from late in the dataset in a box plot
# YOUR CODE HERE
print(f"Plotting the Arbitrage spread (as a box plot) for ONE day in the later part of the dataset - March'15th between 2am & 4am:")
print()
arbitrage_spread_late.plot(kind='box')
# Out:
# Plotting the Arbitrage spread (as a box plot) for ONE day in the later part of the dataset - March'15th between 2am & 4am:
# <AxesSubplot:>

# %% [markdown]
# ### Step 4: Calculate the Arbitrage Profits
#
# Calculate the potential profits for each date that you selected in the previous section. Your goal is to determine whether arbitrage opportunities still exist in the Bitcoin market. Complete the following steps:
#
# 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.
#
# 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.
#
# 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?
#
# 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.
#
# 6. Generate the summary statistics, and plot the results for each of the three DataFrames.
#
# 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.
#
# 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?
#
# (NOTE: The starter code displays only one date. You'll want to do this analysis for two additional dates).

# %% [markdown]
# #### 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# *NOTE*: For illustration, only one of the three dates is shown in the starter code below.

# %%
# For the date early in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one
# YOUR CODE HERE
arbitrage_spread_early = coinbase_sliced.loc['2018-01-15 20' : '2018-01-15 21'] - bitstamp_sliced.loc['2018-01-15 20' : '2018-01-15 21']

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
# YOUR CODE HERE
arbitrage_spread_early_positive = arbitrage_spread_early[arbitrage_spread_early>0]

print(f"Here are the positive values for the 'early' date in the dataset:")
print()
arbitrage_spread_early_positive.describe()
# Out:
# Here are the positive values for the 'early' date in the dataset:
# count     85.000000
# mean      30.767882
# std       21.578672
# min        0.530000
# 25%       15.870000
# 50%       25.010000
# 75%       42.100000
# max      106.080000
# Name: Close, dtype: float64

# %%
# For the date in the middle of the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lowe
arbitrage_spread_middle = coinbase_sliced.loc['2018-02-15 09' : '2018-02-15 10'] - bitstamp_sliced.loc['2018-02-15 09' : '2018-02-15 10']
# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
# YOUR CODE HERE
arbitrage_spread_middle_positive = arbitrage_spread_middle[arbitrage_spread_middle>0]
print(f"Here are the positive values for the 'middle' date in the dataset:")
print()
arbitrage_spread_middle_positive.describe()
# Out:
# Here are the positive values for the 'middle' date in the dataset:
# count    73.000000
# mean      9.761233
# std       6.067572
# min       0.010000
# 25%       5.280000
# 50%       9.840000
# 75%      13.310000
# max      27.480000
# Name: Close, dtype: float64

# %%
# For the date in the later part of the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lowe
arbitrage_spread_late = coinbase_sliced.loc['2018-03-15 02' : '2018-03-15 03'] - bitstamp_sliced.loc['2018-03-15 02' : '2018-03-15 03']
# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
# YOUR CODE HERE
arbitrage_spread_late_positive = arbitrage_spread_late[arbitrage_spread_late>0]
print(f"Here are the positive values for the 'later' date in the dataset:")
print()
arbitrage_spread_late_positive.describe()
# Out:
# Here are the positive values for the 'later' date in the dataset:
# count    19.000000
# mean      5.195789
# std       3.794981
# min       0.010000
# 25%       2.560000
# 50%       4.480000
# 75%       6.215000
# max      15.600000
# Name: Close, dtype: float64

# %% [markdown]
# #### 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).
# YOUR CODE HERE
spread_return_early= arbitrage_spread_early_positive / bitstamp_sliced.loc['2018-01-15 20' : '2018-01-15 21']

# Review the spread return DataFrame
# YOUR CODE HERE
spread_return_early.describe()
# Out:
# count    85.000000
# mean      0.002370
# std       0.001679
# min       0.000040
# 25%       0.001219
# 50%       0.001918
# 75%       0.003256
# max       0.008241
# Name: Close, dtype: float64

# %%
# For the date in middle of the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).
# YOUR CODE HERE
spread_return_middle= arbitrage_spread_middle_positive / bitstamp_sliced.loc['2018-02-15 09' : '2018-02-15 10']

# Review the spread return DataFrame
# YOUR CODE HERE
spread_return_middle.describe()
# Out:
# count    73.000000
# mean      0.000993
# std       0.000618
# min       0.000001
# 25%       0.000538
# 50%       0.001001
# 75%       0.001353
# max       0.002800
# Name: Close, dtype: float64

# %%
# For the date later in the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).
# YOUR CODE HERE
spread_return_late= arbitrage_spread_late_positive / bitstamp_sliced.loc['2018-03-15 02' : '2018-03-15 03']

# Review the spread return DataFrame
# YOUR CODE HERE
spread_return_late.describe()
# Out:
# count    19.000000
# mean      0.000662
# std       0.000483
# min       0.000001
# 25%       0.000324
# 50%       0.000565
# 75%       0.000795
# max       0.001977
# Name: Close, dtype: float64

# %% [markdown]
# #### 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.

# %%
# For the date early in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
# YOUR CODE HERE
profitable_trades_early = spread_return_early[spread_return_early>0]

# Review the first five profitable trades
# YOUR CODE HERE
profitable_trades_early.head()
# Out:
# Timestamp
# 2018-01-15 20:04:00    0.000040
# 2018-01-15 20:05:00    0.001471
# 2018-01-15 20:06:00    0.001603
# 2018-01-15 20:16:00    0.001127
# 2018-01-15 20:17:00    0.000899
# Name: Close, dtype: float64

# %%
# For the date in the middle of the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
# YOUR CODE HERE
profitable_trades_middle = spread_return_middle[spread_return_middle>0]

# Review the first five profitable trades
# YOUR CODE HERE
profitable_trades_middle.head()
# Out:
# Timestamp
# 2018-02-15 09:03:00    0.000735
# 2018-02-15 09:04:00    0.001702
# 2018-02-15 09:19:00    0.000195
# 2018-02-15 09:28:00    0.000752
# 2018-02-15 09:30:00    0.000250
# Name: Close, dtype: float64

# %%
# For the date later in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
# YOUR CODE HERE
profitable_trades_late = spread_return_late[spread_return_late>0]

# Review the first five profitable trades
# YOUR CODE HERE
profitable_trades_late.head()
# Out:
# Timestamp
# 2018-03-15 02:02:00    0.001061
# 2018-03-15 02:04:00    0.000905
# 2018-03-15 02:06:00    0.000504
# 2018-03-15 02:08:00    0.001049
# 2018-03-15 02:56:00    0.000518
# Name: Close, dtype: float64

# %% [markdown]
# #### 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?

# %%
# For the date early in the dataset, generate the summary statistics for the profitable trades
# or you trades where the spread returns are are greater than 1%
# YOUR CODE HERE
profitable_trades_early.describe()
# Out:
# count    85.000000
# mean      0.002370
# std       0.001679
# min       0.000040
# 25%       0.001219
# 50%       0.001918
# 75%       0.003256
# max       0.008241
# Name: Close, dtype: float64

# %%
# For the date in the middle of the dataset, generate the summary statistics for the profitable trades
# or you trades where the spread returns are are greater than 1%
# YOUR CODE HERE
profitable_trades_middle.describe()
# Out:
# count    73.000000
# mean      0.000993
# std       0.000618
# min       0.000001
# 25%       0.000538
# 50%       0.001001
# 75%       0.001353
# max       0.002800
# Name: Close, dtype: float64

# %%
# For the date early in the dataset, generate the summary statistics for the profitable trades
# or you trades where the spread returns are are greater than 1%
# YOUR CODE HERE
profitable_trades_late.describe()
# Out:
# count    19.000000
# mean      0.000662
# std       0.000483
# min       0.000001
# 25%       0.000324
# 50%       0.000565
# 75%       0.000795
# max       0.001977
# Name: Close, dtype: float64

# %% [markdown]
# #### 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased
# YOUR CODE HERE
profit_early = profitable_trades_early * bitstamp_sliced.loc['2018-01-15 20' : '2018-01-15 21']

# Drop any missing values from the profit DataFrame
# YOUR CODE HERE
profit_per_trade_early = profit_early.dropna()

# View the early profit DataFrame
# YOUR CODE HERE
profit_per_trade_early.head()
# Out:
# Timestamp
# 2018-01-15 20:04:00     0.53
# 2018-01-15 20:05:00    19.40
# 2018-01-15 20:06:00    21.20
# 2018-01-15 20:16:00    15.04
# 2018-01-15 20:17:00    11.97
# Name: Close, dtype: float64

# %%
# For the date in the middle of the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased
# YOUR CODE HERE
profit_middle = profitable_trades_middle * bitstamp_sliced.loc['2018-02-15 09' : '2018-02-15 10']

# Drop any missing values from the profit DataFrame
# YOUR CODE HERE
profit_per_trade_middle = profit_middle.dropna()

# View the early profit DataFrame
# YOUR CODE HERE
profit_per_trade_middle.head()
# Out:
# Timestamp
# 2018-02-15 09:03:00     7.11
# 2018-02-15 09:04:00    16.46
# 2018-02-15 09:19:00     1.91
# 2018-02-15 09:28:00     7.36
# 2018-02-15 09:30:00     2.45
# Name: Close, dtype: float64

# %%
# For the date early in the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased
# YOUR CODE HERE
profit_late = profitable_trades_late * bitstamp_sliced.loc['2018-03-15 02' : '2018-03-15 03']

# Drop any missing values from the profit DataFrame
# YOUR CODE HERE
profit_per_trade_late = profit_late.dropna()

# View the early profit DataFrame
# YOUR CODE HERE
profit_per_trade_late.head()
# Out:
# Timestamp
# 2018-03-15 02:02:00    8.24
# 2018-03-15 02:04:00    7.02
# 2018-03-15 02:06:00    3.89
# 2018-03-15 02:08:00    8.06
# 2018-03-15 02:56:00    4.05
# Name: Close, dtype: float64

# %% [markdown]
# #### 6. Generate the summary statistics, and plot the results for each of the three DataFrames.

# %%
# Generate the summary statistics for the early profit per trade DataFrame
# YOUR CODE HERE
profit_per_trade_early.describe()
# Out:
# count     85.000000
# mean      30.767882
# std       21.578672
# min        0.530000
# 25%       15.870000
# 50%       25.010000
# 75%       42.100000
# max      106.080000
# Name: Close, dtype: float64

# %%
# Generate the summary statistics for the early profit per trade DataFrame
# YOUR CODE HERE
profit_per_trade_middle.describe()
# Out:
# count    73.000000
# mean      9.761233
# std       6.067572
# min       0.010000
# 25%       5.280000
# 50%       9.840000
# 75%      13.310000
# max      27.480000
# Name: Close, dtype: float64

# %%
# Generate the summary statistics for the early profit per trade DataFrame
# YOUR CODE HERE
profit_per_trade_late.describe()
# Out:
# count    19.000000
# mean      5.195789
# std       3.794981
# min       0.010000
# 25%       2.560000
# 50%       4.480000
# 75%       6.215000
# max      15.600000
# Name: Close, dtype: float64

# %%
# Plot the results for the early profit per trade DataFrame
# YOUR CODE HERE

# %% [markdown]
# #### 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.

# %%
# Calculate the sum of the potential profits for the early profit per trade DataFrame
# YOUR CODE HERE

# %% [markdown]
# #### 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?

# %%
# Use the cumsum function to calculate the cumulative profits over time for the early profit per trade DataFrame
#cumulative_profit_early = # YOUR CODE HERE

# %%
# Plot the cumulative sum of profits for the early profit per trade DataFrame
# YOUR CODE HERE

# %% [markdown]
# **Question:** After reviewing the profit information across each date from the different time periods, can you identify any patterns or trends?
#
# **Answer:** YOUR ANSWER HERE
